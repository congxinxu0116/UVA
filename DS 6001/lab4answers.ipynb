# %% [markdown]
# # Lab Assignment 4: How to Use APIs in Python
# ## DS 6001: Practice and Application of Data Science
#
# ### Answer Key

# %% [markdown]
# In this lab, you will work with the public API provided by [genius.com](https://genius.com/), a website that calls itself "the world’s biggest collection of song lyrics and musical knowledge." You will need to read the API documentation carefully, acquire an access key, and use it without sharing it to pull data from this API into Python. You will also practice using a library made specifically to wrap around `requests` to make calling from the Genius API easier.
#
# ## Problem 0
# I load the libraries I need and turn off the error tracebacks to make errors easier to read:

# %%
import numpy as np
import pandas as pd
import requests
import json
import os
import dotenv
import sys
sys.tracebacklimit = 0 # turn off the error tracebacks

# %% [markdown]
# ## Problem 1
# The Genius API documentation is here: https://docs.genius.com/#/getting-started-h1. Read through the documentation carefully. Although the Genius API is free and public, it still requires users an access key to use the API. In this case, Genius provides users with three codes: a client ID, a client ID secret, and a client access token. Use the documentation to find a way to obtain these codes for yourself. Write a paragraph that describes all of the steps you needed to take (but DO NOT list your access codes in this paragraph).
#
# Some hints and cautions:
#
# 1. Before you can use the API, you will need a regular, free user account with Genius. Sign-up here: https://genius.com/signup_or_login
#
# 2. Genius's API is built to support third-party app development, not data scientists. The language is entirely geared toward app development. Under "Authentication" there are instructions to third-party developers for guiding their own users in getting access keys. That's not relevant to getting access for yourself. It's not hard to get an access key, but the guidance here is not very clear. Be patient and read everything in the Authentication section carefully.
#
# 3. When you arrive at the page that allows you to register for API access keys, the language is still geared toward app development. You will be prompted to name your app and provide the URLs associated with the app. It doesn't much matter what you name your app, and I just used the Collab main page (https://collab.its.virginia.edu/portal?containerLogin=true) for the URLs.
#
# 4. When you get your codes, copy them in a text file. In problem 2 you will copy these codes over again to a `.env` file. [4 points]

# %% [markdown]
# In the "Authentication" section of the API documentation, I noticed the following language in the right-hand frame:
#
# > Access for Apps Without Users: If your application doesn't include user-specific behaviors you can use the client access token associated with your API instead of tokens for authenticated users. These tokens are only valid for read-only endpoints that are not restricted by a required scope. You can get a client access token by clicking "Generate Access Token" on the API Client management page.
#
# My app will not have users (other than myself), so this language applies to me. This paragraph tells me I can use my own access keys. Further it tells me to click "Generate Access Token" on the API Client management page. But where is the API Client management page? I look around the documentation and see "Manage Clients" at the top of the toolbar to the left of the screen. Sure enough, that takes me to a page in which I can click on "New API Client", then I arrive at the page to name my app. I called my app "Class Example", and I placed https://collab.its.virginia.edu/portal?containerLogin=true in the next three fields. On the next page, I copy the client ID and the client secret to a text file. I click "Generate Access Token" and copy the code that appears to the same text file.

# %% [markdown]
# ## Problem 2
# Create a `.env` file for this project. Open it, copy your access codes into it, and save it. Then use Python code to load the environmental variables contained in the `.env` file, and create variables that contain each of the three codes. (You can print these variables to make sure it worked, but do not allow your access keys to display in your notebook). [4 points]

# %% [markdown]
# I open a console from my notebook's environoment and create a new `.env` file in my working directory by typing `!touch .env`. I then navigate to my working directory (revealing the hidden files if necessary) and open the `.env` file. I paste the keys into the file and save it. Then I load the environmental variables in the `.env` file into Python by typing:

# %%
dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# And I save the keys as Python variables:

# %%
GeniusClient = os.getenv('GeniusClient')
GeniusClientSecret = os.getenv('GeniusClientSecret')
GeniusToken = os.getenv('GeniusToken')

# %% [markdown]
# ## Problem 3
# The root for all Genius APIs is https://api.genius.com. Find the endpoint for the Search API. (You will have to click the "Authorize with Genius" button in the upper-right corner if you haven't already done so). Use the `requests` library to issue a search for Bob Dylan. Genius's API is organized in a way that every individual artist has his or her own API endpoint. Display a portion of the JSON output that displays the API endpoint path for the data on Bob Dylan. [4 points]
#
# Hint: to authenticate, specify your access token (not your client ID or client secret) as the `access_token` parameter. You will have to dig around the JSON output to find the artist ID, but it is listed under `primary_artist` several branches down the JSON tree.

# %% [markdown]
# I specify the endpoint and the parameters and pass these to `requests.get`:

# %%
endpoint = "https://api.genius.com/search"
mypars = {'q':'Bob Dylan',
         'access_token': GeniusToken}
r = requests.get(endpoint, params=mypars)
r
# Out:
# <Response [200]>

# %% [markdown]
# The response of 200 tells me the request was successful, as far as the API is concerned. I dig through the JSON tree and find the information about Bob Dylan:

# %%
searchresult = json.loads(r.text)
searchresult["response"]['hits'][0]['result']['primary_artist']
# Out:
# {'api_path': '/artists/181',
#  'header_image_url': 'https://images.genius.com/facc753d420efc53bbe1e0b63a72d70b.960x719x1.jpg',
#  'id': 181,
#  'image_url': 'https://images.genius.com/22306423b6ad8777d1ed5b33ad8b0d0b.1000x1000x1.jpg',
#  'is_meme_verified': False,
#  'is_verified': False,
#  'name': 'Bob Dylan',
#  'url': 'https://genius.com/artists/Bob-dylan'}

# %% [markdown]
# The endpoint path for the data on Bob Dylan is `/artists/181` which can be added to the end of the root address.

# %% [markdown]
# ## Problem 4
# Add `/songs` to the end of the the endpoint path you found in problem 3 and use this path to request the 20 most popular Bob Dylan songs. Organize these data in a `pandas` data frame. [4 points]

# %% [markdown]
# To extract the top 20 most popular Bob Dylan songs I use the https://api.genius.com/artists/181/songs endpoint, and specify the following parameters as listed in the API documentation:

# %%
endpoint = "https://api.genius.com/artists/181/songs"
mypars = {'sort':'popularity',
         'access_token': GeniusToken}
r = requests.get(endpoint, params=mypars)
r
# Out:
# <Response [200]>

# %%
dylan_json = json.loads(r.text)
dylan_df = pd.json_normalize(dylan_json, record_path = ['response', 'songs'])
dylan_df
# Out:
#     annotation_count        api_path  \
# 0                127  /songs/5393247
# 1                 16    /songs/96286
# 2                 12    /songs/79424
# 3                  1    /songs/68146
# 4                 17    /songs/62605
# 5                  6   /songs/103982
# 6                 15    /songs/98664
# 7                 19    /songs/54784
# 8                  8    /songs/79749
# 9                 12    /songs/63341
# 10                14    /songs/87402
# 11                 9    /songs/84846
# 12                18    /songs/75446
# 13                15   /songs/154239
# 14                31   /songs/105186
# 15                19      /songs/224
# 16                56    /songs/92350
# 17                25   /songs/118799
# 18                26    /songs/62628
# 19                 8   /songs/189270
#
#                                            full_title  \
# 0                       Murder Most Foul by Bob Dylan
# 1                  We Are the World by USA For Africa
# 2                    Blowin' in the Wind by Bob Dylan
# 3                      Make You Feel My Love by Adele
# 4          The Times They Are A-Changin' by Bob Dylan
# 5   Knockin’ on Heaven’s Door by Guns N’ Roses (Ft...
# 6               All Along the Watchtower by Bob Dylan
# 7                   Like a Rolling Stone by Bob Dylan
# 8                  Make You Feel My Love by Bob Dylan
# 9   All Along the Watchtower by The Jimi Hendrix E...
# 10                             Hurricane by Bob Dylan
# 11     Don't Think Twice, It's All Right by Bob Dylan
# 12                    Mr. Tambourine Man by Bob Dylan
# 13                       Wagon Wheel by Darius Rucker
# 14            A Hard Rain's a-Gonna Fall by Bob Dylan
# 15           Subterranean Homesick Blues by Bob Dylan
# 16                        Desolation Row by Bob Dylan
# 17                    Tangled Up in Blue by Bob Dylan
# 18                        Masters of War by Bob Dylan
# 19              End of the Line by Traveling Wilburys
#
#                            header_image_thumbnail_url  \
# 0   https://images.genius.com/7fbaf838ffdf99315408...
# 1   https://images.genius.com/cd231dd0e0159b8c8b25...
# 2   https://images.genius.com/afd28edb1b2d6d5d556a...
# 3   https://images.genius.com/e23228f25b76446cf8de...
# 4   https://images.genius.com/bb0d6623d70dfad2803c...
# 5   https://images.genius.com/cb2614550098bf753ab3...
# 6   https://images.genius.com/f727dfc7b28942c59cd6...
# 7   https://images.genius.com/5de9704b9bd8773ddbcb...
# 8   https://images.genius.com/cd0a26733cc459710d09...
# 9   https://images.genius.com/892e94dacb1ac51070e5...
# 10  https://images.genius.com/2df91ca57456e44cf67e...
# 11  https://images.genius.com/afd28edb1b2d6d5d556a...
# 12  https://images.genius.com/2fb972dceb4a8e726359...
# 13  https://images.genius.com/71f204d1ae373a8a004a...
# 14  https://images.genius.com/afd28edb1b2d6d5d556a...
# 15  https://images.genius.com/2fb972dceb4a8e726359...
# 16  https://images.genius.com/5de9704b9bd8773ddbcb...
# 17  https://images.genius.com/9146ba54ed06288f10b2...
# 18  https://images.genius.com/afd28edb1b2d6d5d556a...
# 19  https://images.genius.com/2f3946547d121a74c225...
#
#                                      header_image_url       id  \
# 0   https://images.genius.com/7fbaf838ffdf99315408...  5393247
# 1   https://images.genius.com/cd231dd0e0159b8c8b25...    96286
# 2   https://images.genius.com/afd28edb1b2d6d5d556a...    79424
# 3   https://images.genius.com/e23228f25b76446cf8de...    68146
# 4   https://images.genius.com/bb0d6623d70dfad2803c...    62605
# 5   https://images.genius.com/cb2614550098bf753ab3...   103982
# 6   https://images.genius.com/f727dfc7b28942c59cd6...    98664
# 7   https://images.genius.com/5de9704b9bd8773ddbcb...    54784
# 8   https://images.genius.com/cd0a26733cc459710d09...    79749
# 9   https://images.genius.com/892e94dacb1ac51070e5...    63341
# 10  https://images.genius.com/2df91ca57456e44cf67e...    87402
# 11  https://images.genius.com/afd28edb1b2d6d5d556a...    84846
# 12  https://images.genius.com/2fb972dceb4a8e726359...    75446
# 13  https://images.genius.com/71f204d1ae373a8a004a...   154239
# 14  https://images.genius.com/afd28edb1b2d6d5d556a...   105186
# 15  https://images.genius.com/2fb972dceb4a8e726359...      224
# 16  https://images.genius.com/5de9704b9bd8773ddbcb...    92350
# 17  https://images.genius.com/9146ba54ed06288f10b2...   118799
# 18  https://images.genius.com/afd28edb1b2d6d5d556a...    62628
# 19  https://images.genius.com/2f3946547d121a74c225...   189270
#
#     lyrics_owner_id lyrics_state  \
# 0           3360167     complete
# 1           4733728     complete
# 2             73267     complete
# 3             82481     complete
# 4             49202     complete
# 5            168784     complete
# 6               779     complete
# 7                 7     complete
# 8              5307     complete
# 9             31298     complete
# 10           132320     complete
# 11           125524     complete
# 12            74226     complete
# 13            10380     complete
# 14               16     complete
# 15                4     complete
# 16           145715     complete
# 17             1850     complete
# 18            49202     complete
# 19            46981     complete
#
#                                                  path  pyongs_count  ...  \
# 0                  /Bob-dylan-murder-most-foul-lyrics            35  ...
# 1             /Usa-for-africa-we-are-the-world-lyrics            29  ...
# 2                /Bob-dylan-blowin-in-the-wind-lyrics            43  ...
# 3                 /Adele-make-you-feel-my-love-lyrics            46  ...
# 4      /Bob-dylan-the-times-they-are-a-changin-lyrics            36  ...
# 5        /Guns-n-roses-knockin-on-heavens-door-lyrics            26  ...
# 6          /Bob-dylan-all-along-the-watchtower-lyrics            40  ...
# 7              /Bob-dylan-like-a-rolling-stone-lyrics            58  ...
# 8             /Bob-dylan-make-you-feel-my-love-lyrics            10  ...
# 9   /The-jimi-hendrix-experience-all-along-the-wat...            55  ...
# 10                        /Bob-dylan-hurricane-lyrics            21  ...
# 11   /Bob-dylan-dont-think-twice-its-all-right-lyrics            21  ...
# 12                /Bob-dylan-mr-tambourine-man-lyrics            19  ...
# 13                  /Darius-rucker-wagon-wheel-lyrics            31  ...
# 14        /Bob-dylan-a-hard-rains-a-gonna-fall-lyrics            20  ...
# 15      /Bob-dylan-subterranean-homesick-blues-lyrics            33  ...
# 16                   /Bob-dylan-desolation-row-lyrics            11  ...
# 17               /Bob-dylan-tangled-up-in-blue-lyrics            23  ...
# 18                   /Bob-dylan-masters-of-war-lyrics            17  ...
# 19         /Traveling-wilburys-end-of-the-line-lyrics             4  ...
#
#    stats.pageviews primary_artist.api_path  \
# 0           439790            /artists/181
# 1           417540         /artists/370890
# 2           384445            /artists/181
# 3           341581           /artists/2300
# 4           306366            /artists/181
# 5           295799            /artists/637
# 6           289566            /artists/181
# 7           275541            /artists/181
# 8           260681            /artists/181
# 9           255230         /artists/634985
# 10          221069            /artists/181
# 11          198955            /artists/181
# 12          181855            /artists/181
# 13          159102          /artists/21867
# 14          130748            /artists/181
# 15          129829            /artists/181
# 16          118906            /artists/181
# 17          114296            /artists/181
# 18          112228            /artists/181
# 19          105871          /artists/60612
#
#                       primary_artist.header_image_url primary_artist.id  \
# 0   https://images.genius.com/facc753d420efc53bbe1...               181
# 1   https://images.genius.com/3fb2d9f68c911b547339...            370890
# 2   https://images.genius.com/facc753d420efc53bbe1...               181
# 3   https://images.genius.com/2a44416083dd36132512...              2300
# 4   https://images.genius.com/facc753d420efc53bbe1...               181
# 5   https://images.genius.com/151b716749a32d2e0d45...               637
# 6   https://images.genius.com/facc753d420efc53bbe1...               181
# 7   https://images.genius.com/facc753d420efc53bbe1...               181
# 8   https://images.genius.com/facc753d420efc53bbe1...               181
# 9   https://images.genius.com/4a0926e479ac3a397a7e...            634985
# 10  https://images.genius.com/facc753d420efc53bbe1...               181
# 11  https://images.genius.com/facc753d420efc53bbe1...               181
# 12  https://images.genius.com/facc753d420efc53bbe1...               181
# 13  https://images.genius.com/6a629cf1a4b6fec5b21a...             21867
# 14  https://images.genius.com/facc753d420efc53bbe1...               181
# 15  https://images.genius.com/facc753d420efc53bbe1...               181
# 16  https://images.genius.com/facc753d420efc53bbe1...               181
# 17  https://images.genius.com/facc753d420efc53bbe1...               181
# 18  https://images.genius.com/facc753d420efc53bbe1...               181
# 19  https://images.genius.com/609e88d8b00dca0919f0...             60612
#
#                              primary_artist.image_url  \
# 0   https://images.genius.com/22306423b6ad8777d1ed...
# 1   https://images.genius.com/3fb2d9f68c911b547339...
# 2   https://images.genius.com/22306423b6ad8777d1ed...
# 3   https://images.genius.com/2dfd665a4ae64d9e2353...
# 4   https://images.genius.com/22306423b6ad8777d1ed...
# 5   https://images.genius.com/6a38c80ced1ad68fa66f...
# 6   https://images.genius.com/22306423b6ad8777d1ed...
# 7   https://images.genius.com/22306423b6ad8777d1ed...
# 8   https://images.genius.com/22306423b6ad8777d1ed...
# 9   https://images.genius.com/06f36798cfdc89d29602...
# 10  https://images.genius.com/22306423b6ad8777d1ed...
# 11  https://images.genius.com/22306423b6ad8777d1ed...
# 12  https://images.genius.com/22306423b6ad8777d1ed...
# 13  https://images.genius.com/0fc3950433f07df236e4...
# 14  https://images.genius.com/22306423b6ad8777d1ed...
# 15  https://images.genius.com/22306423b6ad8777d1ed...
# 16  https://images.genius.com/22306423b6ad8777d1ed...
# 17  https://images.genius.com/22306423b6ad8777d1ed...
# 18  https://images.genius.com/22306423b6ad8777d1ed...
# 19  https://images.genius.com/c859d02ba3a25da3b1f9...
#
#     primary_artist.is_meme_verified  primary_artist.is_verified  \
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                             False                       False
# 5                             False                       False
# 6                             False                       False
# 7                             False                       False
# 8                             False                       False
# 9                             False                       False
# 10                            False                       False
# 11                            False                       False
# 12                            False                       False
# 13                            False                       False
# 14                            False                       False
# 15                            False                       False
# 16                            False                       False
# 17                            False                       False
# 18                            False                       False
# 19                            False                       False
#
#             primary_artist.name  \
# 0                     Bob Dylan
# 1                USA For Africa
# 2                     Bob Dylan
# 3                         Adele
# 4                     Bob Dylan
# 5                 Guns N’ Roses
# 6                     Bob Dylan
# 7                     Bob Dylan
# 8                     Bob Dylan
# 9   The Jimi Hendrix Experience
# 10                    Bob Dylan
# 11                    Bob Dylan
# 12                    Bob Dylan
# 13                Darius Rucker
# 14                    Bob Dylan
# 15                    Bob Dylan
# 16                    Bob Dylan
# 17                    Bob Dylan
# 18                    Bob Dylan
# 19           Traveling Wilburys
#
#                                    primary_artist.url stats.concurrents
# 0                https://genius.com/artists/Bob-dylan               NaN
# 1           https://genius.com/artists/Usa-for-africa               NaN
# 2                https://genius.com/artists/Bob-dylan               2.0
# 3                    https://genius.com/artists/Adele               NaN
# 4                https://genius.com/artists/Bob-dylan               2.0
# 5             https://genius.com/artists/Guns-n-roses               2.0
# 6                https://genius.com/artists/Bob-dylan               NaN
# 7                https://genius.com/artists/Bob-dylan               NaN
# 8                https://genius.com/artists/Bob-dylan               NaN
# 9   https://genius.com/artists/The-jimi-hendrix-ex...               5.0
# 10               https://genius.com/artists/Bob-dylan               NaN
# 11               https://genius.com/artists/Bob-dylan               NaN
# 12               https://genius.com/artists/Bob-dylan               NaN
# 13           https://genius.com/artists/Darius-rucker               NaN
# 14               https://genius.com/artists/Bob-dylan               2.0
# 15               https://genius.com/artists/Bob-dylan               NaN
# 16               https://genius.com/artists/Bob-dylan               NaN
# 17               https://genius.com/artists/Bob-dylan               NaN
# 18               https://genius.com/artists/Bob-dylan               NaN
# 19      https://genius.com/artists/Traveling-wilburys               NaN
#
# [20 rows x 27 columns]

# %% [markdown]
# ## Problem 5
# Install and import the `lyricsgenius` library in Python, which is a wrapper around `requests` that works specifically with the Genius API. . Follow the guide on the GitHub repository for this library (https://github.com/johnwmillr/LyricsGenius) for instructions on using the library. Use the `lyricsgenius` library to download and display the lyrics to "Tangled Up in Blue" by Bob Dylan. [4 points]

# %%
import lyricsgenius
genius = lyricsgenius.Genius(GeniusToken)
artist = genius.search_artist("Bob Dylan", max_songs=3, sort="title")
song = genius.search_song("Tangled Up in Blue", artist.name)
song.lyrics
# Out:
# Searching for songs by Bob Dylan...
#
# Song 1: "10,000 Men"
# Song 2: "2 X 2"
# Song 3: "32-20 Blues"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Tangled Up in Blue" by Bob Dylan...
# Done.
# '[Verse 1]\nEarly one morning the sun was shining\nI was laying in bed\nWondering if she\'d changed at all\nIf her hair was still red\nHer folks they said our lives together\nSure was going to be rough\nThey never did like Mama\'s homemade dress\nPapa\'s bankbook wasn\'t big enough\nAnd I was standing on the side of the road\nRain falling on my shoes\nHeading out for the East Coast\nLord knows I\'ve paid some dues\nGetting through\nTangled up in blue\n\n[Verse 2]\nShe was married when we first met\nSoon to be divorced\nI helped her out of a jam, I guess\nBut I used a little too much force\nWe drove that car as far as we could\nAbandoned it out West\nSplit up on a dark sad night\nBoth agreeing it was best\nShe turned around to look at me\nAs I was walking away\nI heard her say over my shoulder\n"We\'ll meet again someday\nOn the avenue"\nTangled up in blue\n\n[Verse 3]\nI had a job in the great north woods\nWorking as a cook for a spell\nBut I never did like it all that much\nAnd one day the ax just fell\nSo I drifted down to New Orleans\nWhere I lucky was to be employed\nWorking for a while on a fishing boat\nRight outside of Delacroix\nBut all the while I was alone\nThe past was close behind\nI seen a lot of women\nBut she never escaped my mind\nAnd I just grew\nTangled up in blue\n\n[Verse 4]\nShe was working in a topless place\nAnd I stopped in for a beer\nI just kept looking at the side of her face\nIn the spotlight, so clear\nAnd later on, when the crowd thinned out\nI was just about to do the same\nShe was standing there, in back of my chair\nSaid to me "Tell me, don\'t I know your name?"\nI muttered something underneath my breath\nShe studied the lines on my face\nI must admit, I felt a little uneasy\nWhen she bent down to tie the laces\nOf my shoe\nTangled up in blue\n\n[Verse 5]\nShe lit a burner on the stove\nAnd offered me a pipe\n"I thought you\'d never say hello" she said\n"You look like the silent type"\nThen she opened up a book of poems\nAnd handed it to me\nWritten by an Italian poet\nFrom the thirteenth century\nAnd every one of them words rang true\nAnd glowed like burning coal\nPouring off of every page\nLike it was written in my soul\nFrom me to you\nTangled up in blue\n\n[Verse 6]\nI lived with them on Montague Street\nIn a basement down the stairs\nThere was music in the cafes at night\nAnd revolution in the air\nThen he started into dealing with slaves\nAnd something inside of him died\nShe had to sell everything she owned\nAnd froze up inside\nAnd when it finally, the bottom fell out\nI became withdrawn\nThe only thing I knew how to do\nWas to keep on keeping on\nLike a bird that flew\nTangled up in blue\n\n[Verse 7]\nSo now I\'m going back again\nI got to get to her somehow\nAll the people we used to know\nThey\'re an illusion to me now\nSome are mathematicians\nSome are carpenter\'s wives\nDon\'t know how it all got started\nI don\'t know what they\'re doing with their lives\nBut me, I\'m still on the road\nA-heading for another joint\nWe always did feel the same\nWe just saw it from a different point\nOf view\nTangled up in blue'
