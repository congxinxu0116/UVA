# %%
import numpy as np

data = np.genfromtxt('data/example_data.csv', 
                     delimiter=';',
                     names=True, 
                     dtype=None, 
                     encoding='UTF')
data
# Out:
# array([('2018-10-13 11:10:23.560', '262km NW of Ozernovskiy, Russia', 'mww', 6.7, 'green', 1),
#        ('2018-10-13 04:34:15.580', '25km E of Bitung, Indonesia', 'mww', 5.2, 'green', 0),
#        ('2018-10-13 00:13:46.220', '42km WNW of Sola, Vanuatu', 'mww', 5.7, 'green', 0),
#        ('2018-10-12 21:09:49.240', '13km E of Nueva Concepcion, Guatemala', 'mww', 5.7, 'green', 0),
#        ('2018-10-12 02:52:03.620', '128km SE of Kimbe, Papua New Guinea', 'mww', 5.6, 'green', 1)],
#       dtype=[('time', '<U23'), ('place', '<U37'), ('magType', '<U3'), ('mag', '<f8'), ('alert', '<U5'), ('tsunami', '<i4')])

# %%
data.shape
# Out:
# (5,)

# %%
data.dtype
# Out:
# dtype([('time', '<U23'), ('place', '<U37'), ('magType', '<U3'), ('mag', '<f8'), ('alert', '<U5'), ('tsunami', '<i4')])

# %%
# %%timeit
max([row[3] for row in data])
# Out:
# 4.04 µs ± 201 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
array_dict = {}
for i, col in enumerate(data.dtype.names):
    array_dict[col] = np.array([row[i] for row in data])

array_dict
# Out:
# {'time': array(['2018-10-13 11:10:23.560', '2018-10-13 04:34:15.580',
#         '2018-10-13 00:13:46.220', '2018-10-12 21:09:49.240',
#         '2018-10-12 02:52:03.620'], dtype='<U23'),
#  'place': array(['262km NW of Ozernovskiy, Russia', '25km E of Bitung, Indonesia',
#         '42km WNW of Sola, Vanuatu',
#         '13km E of Nueva Concepcion, Guatemala',
#         '128km SE of Kimbe, Papua New Guinea'], dtype='<U37'),
#  'magType': array(['mww', 'mww', 'mww', 'mww', 'mww'], dtype='<U3'),
#  'mag': array([6.7, 5.2, 5.7, 5.7, 5.6]),
#  'alert': array(['green', 'green', 'green', 'green', 'green'], dtype='<U5'),
#  'tsunami': array([1, 0, 0, 0, 1])}

# %%
# %%timeit
array_dict['mag'].max()
# Out:
# 2.01 µs ± 43.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
np.array([
    value[array_dict['mag'].argmax()] \
    for key, value in array_dict.items()
])
# Out:
# array(['2018-10-13 11:10:23.560', '262km NW of Ozernovskiy, Russia',
#        'mww', '6.7', 'green', '1'], dtype='<U31')

# %%
import pandas as pd
place = pd.Series(array_dict['place'], name='place')
place
# Out:
# 0          262km NW of Ozernovskiy, Russia
# 1              25km E of Bitung, Indonesia
# 2                42km WNW of Sola, Vanuatu
# 3    13km E of Nueva Concepcion, Guatemala
# 4      128km SE of Kimbe, Papua New Guinea
# Name: place, dtype: object

# %%
place_index = place.index
place_index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
place_index.values
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
np.array([1, 1, 1]) + np.array([-1, 0, 1])
# Out:
# array([0, 1, 2])

# %%
pd.Series(np.linspace(0, 10, num=5))\
+ pd.Series(np.linspace(0, 10, num=5), index=pd.Index([1, 2, 3, 4, 5]))
# Out:
# 0     NaN
# 1     2.5
# 2     7.5
# 3    12.5
# 4    17.5
# 5     NaN
# dtype: float64

# %%
df = pd.DataFrame(array_dict) 
df
# Out:
#                       time                                  place magType  \
# 0  2018-10-13 11:10:23.560        262km NW of Ozernovskiy, Russia     mww
# 1  2018-10-13 04:34:15.580            25km E of Bitung, Indonesia     mww
# 2  2018-10-13 00:13:46.220              42km WNW of Sola, Vanuatu     mww
# 3  2018-10-12 21:09:49.240  13km E of Nueva Concepcion, Guatemala     mww
# 4  2018-10-12 02:52:03.620    128km SE of Kimbe, Papua New Guinea     mww
#
#    mag  alert  tsunami
# 0  6.7  green        1
# 1  5.2  green        0
# 2  5.7  green        0
# 3  5.7  green        0
# 4  5.6  green        1

# %%
df.dtypes
# Out:
# time        object
# place       object
# magType     object
# mag        float64
# alert       object
# tsunami      int32
# dtype: object

# %%
df.values
# Out:
# array([['2018-10-13 11:10:23.560', '262km NW of Ozernovskiy, Russia',
#         'mww', 6.7, 'green', 1],
#        ['2018-10-13 04:34:15.580', '25km E of Bitung, Indonesia', 'mww',
#         5.2, 'green', 0],
#        ['2018-10-13 00:13:46.220', '42km WNW of Sola, Vanuatu', 'mww',
#         5.7, 'green', 0],
#        ['2018-10-12 21:09:49.240',
#         '13km E of Nueva Concepcion, Guatemala', 'mww', 5.7, 'green', 0],
#        ['2018-10-12 02:52:03.620', '128km SE of Kimbe, Papua New Guinea',
#         'mww', 5.6, 'green', 1]], dtype=object)

# %%
df.columns
# Out:
# Index(['time', 'place', 'magType', 'mag', 'alert', 'tsunami'], dtype='object')

# %%
df + df
# Out:
#                                              time  \
# 0  2018-10-13 11:10:23.5602018-10-13 11:10:23.560
# 1  2018-10-13 04:34:15.5802018-10-13 04:34:15.580
# 2  2018-10-13 00:13:46.2202018-10-13 00:13:46.220
# 3  2018-10-12 21:09:49.2402018-10-12 21:09:49.240
# 4  2018-10-12 02:52:03.6202018-10-12 02:52:03.620
#
#                                                place magType   mag  \
# 0  262km NW of Ozernovskiy, Russia262km NW of Oze...  mwwmww  13.4
# 1  25km E of Bitung, Indonesia25km E of Bitung, I...  mwwmww  10.4
# 2  42km WNW of Sola, Vanuatu42km WNW of Sola, Van...  mwwmww  11.4
# 3  13km E of Nueva Concepcion, Guatemala13km E of...  mwwmww  11.4
# 4  128km SE of Kimbe, Papua New Guinea128km SE of...  mwwmww  11.2
#
#         alert  tsunami
# 0  greengreen        2
# 1  greengreen        0
# 2  greengreen        0
# 3  greengreen        0
# 4  greengreen        2

# %%
import datetime

# %%
np.random.seed(0)
pd.Series(np.random.rand(5), name='random')
# Out:
# 0    0.548814
# 1    0.715189
# 2    0.602763
# 3    0.544883
# 4    0.423655
# Name: random, dtype: float64

# %%
np.random.seed(0)
pd.DataFrame(
    {
        'random': np.random.rand(5),
        'text': ['hot', 'warm', 'cool', 'cold', None],
        'truth': [np.random.choice([True, False]) 
                  for _ in range(5)]
    }, 
    index=pd.date_range(
        end=datetime.date(2019, 4, 21),
        freq='1D',
        periods=5, 
        name='date'
    )
)
# Out:
#               random  text  truth
# date
# 2019-04-17  0.548814   hot  False
# 2019-04-18  0.715189  warm   True
# 2019-04-19  0.602763  cool   True
# 2019-04-20  0.544883  cold  False
# 2019-04-21  0.423655  None   True

# %%
pd.DataFrame([
         {'mag' : 5.2, 'place' : 'California'},
         {'mag' : 1.2, 'place' : 'Alaska'},
         {'mag' : 0.2, 'place' : 'California'},
])
# Out:
#    mag       place
# 0  5.2  California
# 1  1.2      Alaska
# 2  0.2  California

# %%
df = pd.read_csv('data/earthquakes.csv')
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 26 columns]

# %%
import sqlite3
with sqlite3.connect('data/quakes.db') as connection:
    tsunamis = pd.read_sql('SELECT * FROM tsunamis', connection)

tsunamis.head()
# Out:
#    alert        type                                              title  \
# 0   None  earthquake  M 5.0 - 165km NNW of Flying Fish Cove, Christm...
# 1  green  earthquake            M 6.7 - 262km NW of Ozernovskiy, Russia
# 2  green  earthquake        M 5.6 - 128km SE of Kimbe, Papua New Guinea
# 3  green  earthquake         M 6.5 - 148km S of Severo-Kuril'sk, Russia
# 4  green  earthquake        M 6.2 - 94km SW of Kokopo, Papua New Guinea
#
#                                              place magType  mag           time
# 0  165km NNW of Flying Fish Cove, Christmas Island     mww  5.0  1539459504090
# 1                  262km NW of Ozernovskiy, Russia     mww  6.7  1539429023560
# 2              128km SE of Kimbe, Papua New Guinea     mww  5.6  1539312723620
# 3               148km S of Severo-Kuril'sk, Russia     mww  6.5  1539213362130
# 4              94km SW of Kokopo, Papua New Guinea     mww  6.2  1539208835130

# %%
pd.read_csv("data/epidemic.csv",skiprows=[0, 2], header = 1)
# Out:
#        Country  Population  Cases
# 0  Afghanistan   389465464   1412
# 1      Albania    28461651    103
# 2      Algeria    43851044   1949

# %%
df = pd.read_csv('http://data-fairfaxcountygis.opendata.arcgis.com/datasets/533db4de13ae4d729884b5ec41d65034_0.csv')
df.inspection()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-5e191a38d4ca> in <module>
#       1 df = pd.read_csv('http://data-fairfaxcountygis.opendata.arcgis.com/datasets/533db4de13ae4d729884b5ec41d65034_0.csv')
# ----> 2 df.inspection()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'inspection'

# %%
df.tail()
# Out:
#                  LASTUPDATE  OBJECTID  PRECINCTID         NAME   COUNTY  \
# 240  2016/11/17 10:58:50+00       241         201    ARMSTRONG  Fairfax
# 241  2016/11/17 10:58:50+00       242         233  NORTH POINT  Fairfax
# 242  2016/11/17 10:58:50+00       243         735      ROTONDA  Fairfax
# 243  1970/01/01 00:00:00+00      1000       99999     ABSENTEE  Fairfax
# 244  1970/01/01 00:00:00+00      1001       99998  PROVISIONAL  Fairfax
#
#     LASTEDITOR  PRECINCTID_1       NAME_1        TOWNSHIP  \
# 240     stulad           201    ARMSTRONG  Fairfax County
# 241     stulad           233  NORTH POINT  Fairfax County
# 242     stulad           735      ROTONDA  Fairfax County
# 243        NaN         99999     ABSENTEE  Fairfax County
# 244        NaN         99998  PROVISIONAL  Fairfax County
#
#                 WINPARTY  ...          CANDIDATE4              PARTY4  \
# 240  Clinton / Kaine (D)  ...  Stein / Baraka (G)  Stein / Baraka (G)
# 241  Clinton / Kaine (D)  ...  Stein / Baraka (G)  Stein / Baraka (G)
# 242  Clinton / Kaine (D)  ...  Stein / Baraka (G)  Stein / Baraka (G)
# 243                  NaN  ...  Stein / Baraka (G)  Stein / Baraka (G)
# 244                  NaN  ...  Stein / Baraka (G)  Stein / Baraka (G)
#
#      NUMVOTES4  PERCVOTE4              CANDIDATE5                  PARTY5  \
# 240         17   0.005461  McMullin / Johnson (I)  McMullin / Johnson (I)
# 241         17   0.005670  McMullin / Johnson (I)  McMullin / Johnson (I)
# 242         21   0.020369  McMullin / Johnson (I)  McMullin / Johnson (I)
# 243        726        NaN  McMullin / Johnson (I)  McMullin / Johnson (I)
# 244          5        NaN  McMullin / Johnson (I)  McMullin / Johnson (I)
#
#     NUMVOTES5  PERCVOTE5   Shape__Area Shape__Length
# 240        51   0.016383  2.966847e+07  25881.328984
# 241        29   0.009673  4.827039e+07  36216.367462
# 242        14   0.013579  7.376918e+06  12615.457685
# 243      1880        NaN           NaN           NaN
# 244        17        NaN           NaN           NaN
#
# [5 rows x 37 columns]

# %%
df['check'] = df['OBJECTID'] > 241
df
# Out:
#                  LASTUPDATE  OBJECTID  PRECINCTID              NAME   COUNTY  \
# 0    2016/11/17 10:58:50+00       241         623             ALBAN  Fairfax
# 1    2016/11/17 10:58:50+00       241         626          SARATOGA  Fairfax
# 2    2016/11/17 10:58:50+00       241         421        KINGSTOWNE  Fairfax
# 3    2016/11/17 10:58:50+00       241         426       GREENSPRING  Fairfax
# 4    2016/11/17 10:58:50+00       241         840  WEST SPRINGFIELD  Fairfax
# ..                      ...       ...         ...               ...      ...
# 240  2016/11/17 10:58:50+00       241         201         ARMSTRONG  Fairfax
# 241  2016/11/17 10:58:50+00       241         233       NORTH POINT  Fairfax
# 242  2016/11/17 10:58:50+00       241         735           ROTONDA  Fairfax
# 243  1970/01/01 00:00:00+00       241       99999          ABSENTEE  Fairfax
# 244  1970/01/01 00:00:00+00       241       99998       PROVISIONAL  Fairfax
#
#     LASTEDITOR  PRECINCTID_1            NAME_1        TOWNSHIP  \
# 0       stulad           623             ALBAN  Fairfax County
# 1       stulad           626          SARATOGA  Fairfax County
# 2       stulad           421        KINGSTOWNE  Fairfax County
# 3       stulad           426       GREENSPRING  Fairfax County
# 4       stulad           840  WEST SPRINGFIELD  Fairfax County
# ..         ...           ...               ...             ...
# 240     stulad           201         ARMSTRONG  Fairfax County
# 241     stulad           233       NORTH POINT  Fairfax County
# 242     stulad           735           ROTONDA  Fairfax County
# 243        NaN         99999          ABSENTEE  Fairfax County
# 244        NaN         99998       PROVISIONAL  Fairfax County
#
#                 WINPARTY  ...              PARTY4  NUMVOTES4  PERCVOTE4  \
# 0    Clinton / Kaine (D)  ...  Stein / Baraka (G)         21   0.008812
# 1    Clinton / Kaine (D)  ...  Stein / Baraka (G)         23   0.007877
# 2    Clinton / Kaine (D)  ...  Stein / Baraka (G)         18   0.005929
# 3    Clinton / Kaine (D)  ...  Stein / Baraka (G)          1   0.000666
# 4    Clinton / Kaine (D)  ...  Stein / Baraka (G)         17   0.006612
# ..                   ...  ...                 ...        ...        ...
# 240  Clinton / Kaine (D)  ...  Stein / Baraka (G)         17   0.005461
# 241  Clinton / Kaine (D)  ...  Stein / Baraka (G)         17   0.005670
# 242  Clinton / Kaine (D)  ...  Stein / Baraka (G)         21   0.020369
# 243                  NaN  ...  Stein / Baraka (G)        726        NaN
# 244                  NaN  ...  Stein / Baraka (G)          5        NaN
#
#                  CANDIDATE5                  PARTY5 NUMVOTES5 PERCVOTE5  \
# 0    McMullin / Johnson (I)  McMullin / Johnson (I)        37  0.015527
# 1    McMullin / Johnson (I)  McMullin / Johnson (I)        41  0.014041
# 2    McMullin / Johnson (I)  McMullin / Johnson (I)        41  0.013505
# 3    McMullin / Johnson (I)  McMullin / Johnson (I)        17  0.011326
# 4    McMullin / Johnson (I)  McMullin / Johnson (I)        55  0.021392
# ..                      ...                     ...       ...       ...
# 240  McMullin / Johnson (I)  McMullin / Johnson (I)        51  0.016383
# 241  McMullin / Johnson (I)  McMullin / Johnson (I)        29  0.009673
# 242  McMullin / Johnson (I)  McMullin / Johnson (I)        14  0.013579
# 243  McMullin / Johnson (I)  McMullin / Johnson (I)      1880       NaN
# 244  McMullin / Johnson (I)  McMullin / Johnson (I)        17       NaN
#
#       Shape__Area  Shape__Length  check
# 0    6.141624e+07   44406.211569  False
# 1    2.881603e+07   28082.575577  False
# 2    2.253961e+07   23110.064289  False
# 3    3.962441e+06   10051.875337  False
# 4    2.786030e+07   32432.609862  False
# ..            ...            ...    ...
# 240  2.966847e+07   25881.328984  False
# 241  4.827039e+07   36216.367462  False
# 242  7.376918e+06   12615.457685  False
# 243           NaN            NaN  False
# 244           NaN            NaN  False
#
# [245 rows x 38 columns]

# %%
df.drop([1], inplace= True)
df.head()
# Out:
#                LASTUPDATE  OBJECTID  PRECINCTID              NAME   COUNTY  \
# 2  2016/11/17 10:58:50+00       241         421        KINGSTOWNE  Fairfax
# 3  2016/11/17 10:58:50+00       241         426       GREENSPRING  Fairfax
# 4  2016/11/17 10:58:50+00       241         840  WEST SPRINGFIELD  Fairfax
# 5  2016/11/17 10:58:50+00       241         825        CHERRY RUN  Fairfax
# 6  2016/11/17 10:58:50+00       241         812            VALLEY  Fairfax
#
#   LASTEDITOR  PRECINCTID_1            NAME_1        TOWNSHIP  \
# 2     stulad           421        KINGSTOWNE  Fairfax County
# 3     stulad           426       GREENSPRING  Fairfax County
# 4     stulad           840  WEST SPRINGFIELD  Fairfax County
# 5     stulad           825        CHERRY RUN  Fairfax County
# 6     stulad           812            VALLEY  Fairfax County
#
#               WINPARTY  ...              PARTY4  NUMVOTES4  PERCVOTE4  \
# 2  Clinton / Kaine (D)  ...  Stein / Baraka (G)         18   0.005929
# 3  Clinton / Kaine (D)  ...  Stein / Baraka (G)          1   0.000666
# 4  Clinton / Kaine (D)  ...  Stein / Baraka (G)         17   0.006612
# 5  Clinton / Kaine (D)  ...  Stein / Baraka (G)          7   0.002902
# 6  Clinton / Kaine (D)  ...  Stein / Baraka (G)         10   0.004186
#
#                CANDIDATE5                  PARTY5 NUMVOTES5 PERCVOTE5  \
# 2  McMullin / Johnson (I)  McMullin / Johnson (I)        41  0.013505
# 3  McMullin / Johnson (I)  McMullin / Johnson (I)        17  0.011326
# 4  McMullin / Johnson (I)  McMullin / Johnson (I)        55  0.021392
# 5  McMullin / Johnson (I)  McMullin / Johnson (I)        41  0.016998
# 6  McMullin / Johnson (I)  McMullin / Johnson (I)        40  0.016743
#
#     Shape__Area  Shape__Length  check
# 2  2.253961e+07   23110.064289  False
# 3  3.962441e+06   10051.875337  False
# 4  2.786030e+07   32432.609862  False
# 5  2.445997e+07   24305.884623  False
# 6  2.409191e+07   28773.685005  False
#
# [5 rows x 38 columns]
